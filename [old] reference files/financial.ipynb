# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='ERO5XRBZNWQ9E608')

# %%
data, meta_data = ts.get_intraday('INTC')

# %%
ts = TimeSeries(key='ERO5XRBZNWQ9E608', rapidapi=True)

# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
pprint(data.head(2))
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2020-02-10 16:00:00   188.82   188.83  188.64    188.74   625902.0
# 2020-02-10 15:59:00   188.83   188.84  188.72    188.81   276171.0

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key='YOUR_API_KEY', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='INTC',interval='60min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
ts = TimeSeries(key='YOUR_API_KEY',output_format='pandas')
data, meta_data = ts.get_intraday(symbol='TSE:TD',interval='1min', outputsize='full')
print(data)
data['4. close'].plot()
plt.title('Intraday TimeSeries Google')
plt.show()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2020-02-10 16:00:00    75.60    75.63  75.600     75.62    25635.0
# 2020-02-10 15:59:00    75.57    75.60  75.570     75.60    19859.0
# 2020-02-10 15:58:00    75.57    75.58  75.560     75.56    10550.0
# 2020-02-10 15:57:00    75.57    75.58  75.570     75.58     3300.0
# 2020-02-10 15:56:00    75.59    75.59  75.575     75.58     4900.0
# ...                      ...      ...     ...       ...        ...
# 2020-02-04 09:36:00    74.00    74.15  74.000     74.11    37568.0
# 2020-02-04 09:35:00    73.98    74.06  73.970     74.00    19111.0
# 2020-02-04 09:34:00    74.01    74.04  73.980     74.00    20104.0
# 2020-02-04 09:33:00    74.13    74.14  73.980     74.00    40622.0
# 2020-02-04 09:32:00    74.03    74.15  74.010     74.12   222040.0
#
# [1921 rows x 5 columns]
